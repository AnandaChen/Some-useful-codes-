# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
xxx=[]
yyy=[]
zzz=[]
for i in range(0,108):
    for j in range(0,100):
            xxx.append(round(-0.99+0.02*j,2))
            yyy.append(round(-0.991+0.1852*i,2))

# %%
with open('t2.txt') as f:
  rows,cols=np.fromfile(f, dtype=int, count=2, sep=" ")
  data = np.fromfile(f, dtype=int, count=cols*rows, sep=" ").reshape((rows,cols))

# %%
with open('t0.txt') as f:

    array = [[float(x) for x in line.split()] for line in f]
xxx=[]
yyy=[]
zzz=[]
for i in range(0,108):
    for j in range(0,100):
            xxx.append(round(-0.99+0.02*j,2))
            #yyy.append(round(-0.99+0.02*i,2))
            yyy.append(round(-0.991+0.01852*i,5))
            zzz.append(array[i][j])
xxx=np.array(xxx)
yyy=np.array(yyy)
zzz=np.array(zzz)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.tri as mtri

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import


fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_trisurf(xxx, yyy, zzz)#, triangles=tri.triangles, cmap=plt.cm.Spectral)
ax.set_zlim(0, 1)
ax.set_title('T=0.000')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.view_init(elev=20., azim=220)
